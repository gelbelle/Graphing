# %%
import pandas as pd

df = pd.read_csv("data/provincial_voting_results.csv").round(2)

df.head()
# Out:
#               EVENT_NAME  EVENT_YEAR ED_ABBREVIATION       ED_NAME VA_CODE
# 0  2005 General Election        2005             CMX  Comox Valley     NaN  \
# 1  2005 General Election        2005             CMX  Comox Valley     NaN
# 2  2005 General Election        2005             CMX  Comox Valley     NaN
# 3  2005 General Election        2005             CMX  Comox Valley     NaN
# 4  2005 General Election        2005             CMX  Comox Valley     NaN
#
#   EDVA_CODE ADVANCE_VOTING_LOCATION  ADDRESS_STANDARD_ID VOTING_OPPORTUNITY
# 0       NaN                   Comox            3001341.0     Advance voting  \
# 1       NaN                   Comox            3001341.0     Advance voting
# 2       NaN                   Comox            3001341.0     Advance voting
# 3       NaN                   Comox            3001341.0     Advance voting
# 4       NaN                   Comox            3001341.0     Advance voting
#
# ...

# %%
df = df.loc[df["ED_NAME"].isin(["Comox Valley", "North Island"])]
df.head(50)
# Out:
#                EVENT_NAME  EVENT_YEAR ED_ABBREVIATION       ED_NAME VA_CODE
# 0   2005 General Election        2005             CMX  Comox Valley     NaN  \
# 1   2005 General Election        2005             CMX  Comox Valley     NaN
# 2   2005 General Election        2005             CMX  Comox Valley     NaN
# 3   2005 General Election        2005             CMX  Comox Valley     NaN
# 4   2005 General Election        2005             CMX  Comox Valley     NaN
# 5   2005 General Election        2005             CMX  Comox Valley     NaN
# 6   2005 General Election        2005             CMX  Comox Valley     NaN
# 7   2005 General Election        2005             CMX  Comox Valley     NaN
# 8   2005 General Election        2005             CMX  Comox Valley     NaN
# 9   2005 General Election        2005             CMX  Comox Valley     NaN
# 10  2005 General Election        2005             CMX  Comox Valley     NaN
# ...
